# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.read_csv('UN.csv')
# Out:
#                  country   region   tfr  contraception  educationMale  \
# 0            Afghanistan     Asia  6.90            NaN            NaN
# 1                Albania   Europe  2.60            NaN            NaN
# 2                Algeria   Africa  3.81             52           11.1
# 3         American.Samoa     Asia   NaN            NaN            NaN
# 4                Andorra   Europe   NaN            NaN            NaN
# 5                 Angola   Africa  6.69            NaN            NaN
# 6                Antigua  America   NaN             53            NaN
# 7              Argentina  America  2.62            NaN            NaN
# 8                Armenia   Europe  1.70             22            NaN
# 9              Australia  Oceania  1.89             76           16.3
# 10               Austria   Europe  1.42             71           14.4
# 11            Azerbaijan     Asia  2.30             17            NaN
# ...

# %%
A=pd.read_csv('UN.csv')

# %%
A
# Out:
#                  country   region   tfr  contraception  educationMale  \
# 0            Afghanistan     Asia  6.90            NaN            NaN
# 1                Albania   Europe  2.60            NaN            NaN
# 2                Algeria   Africa  3.81             52           11.1
# 3         American.Samoa     Asia   NaN            NaN            NaN
# 4                Andorra   Europe   NaN            NaN            NaN
# 5                 Angola   Africa  6.69            NaN            NaN
# 6                Antigua  America   NaN             53            NaN
# 7              Argentina  America  2.62            NaN            NaN
# 8                Armenia   Europe  1.70             22            NaN
# 9              Australia  Oceania  1.89             76           16.3
# 10               Austria   Europe  1.42             71           14.4
# 11            Azerbaijan     Asia  2.30             17            NaN
# ...

# %%
B=dropna(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-1d5e0ba8079b> in <module>()
# ----> 1 B=dropna(A)
#
# NameError: name 'dropna' is not defined

# %%
A=A.dropna()

# %%
A
# Out:
#                  country   region   tfr  contraception  educationMale  \
# 2                Algeria   Africa  3.81             52           11.1
# 12               Bahamas  America  1.95             62           12.1
# 13               Bahrain     Asia  2.97             53           12.6
# 18                Belize  America  3.66             47           10.6
# 23              Botswana   Africa  4.45             33           10.5
# 27          Burkina.Faso   Africa  6.57              8            3.3
# 28               Burundi   Africa  6.28              9            5.1
# 35                 Chile  America  2.44             30           11.8
# 43                  Cuba  America  1.55             70           10.9
# 50    Dominican.Republic  America  2.80             64           11.1
# 53                 Egypt   Africa  3.40             47           10.8
# 54           El.Salvador  America  3.09             53            9.6
# ...

# %%
pyplot.hist(country, lifeMale color = 'yellow',edgecolor = 'red')
pyplot.xlabel('valeurs')
pyplot.ylabel('nombres')
pyplot.title('Exemple d\' histogramme simple')
# Out:
#   File "<ipython-input-10-00a7c1578636>", line 1
#     pyplot.hist(country, lifeMale color = 'yellow',edgecolor = 'red')
#                                       ^
# SyntaxError: invalid syntax

# %%
plt.plot.hist('tfr')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-44ffd798a35c> in <module>()
#       1
# ----> 2 plt.plot.hist('tfr')
#
# AttributeError: 'function' object has no attribute 'hist'

# %%
import matplotlib.pyplot as plt
pyplot(x='country', y='tfr')
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-15f8efc29872> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 pyplot(x='country', y='tfr')
#       3 plot.show()
#
# NameError: name 'pyplot' is not defined

# %%
plt.pyplot.scatter(region,tfr )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-9162b323bdc6> in <module>()
# ----> 1 plt.pyplot.scatter(region,tfr )
#
# AttributeError: 'module' object has no attribute 'pyplot'

# %%
tfr=A['tfr']

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4])
plt.show()

# %%
plt.plot([country,tfr])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-fd7ffd54e0c0> in <module>()
# ----> 1 plt.plot([country,tfr])
#
# NameError: name 'country' is not defined

# %%
A
# Out:
#                  country   region   tfr  contraception  educationMale  \
# 2                Algeria   Africa  3.81             52           11.1
# 12               Bahamas  America  1.95             62           12.1
# 13               Bahrain     Asia  2.97             53           12.6
# 18                Belize  America  3.66             47           10.6
# 23              Botswana   Africa  4.45             33           10.5
# 27          Burkina.Faso   Africa  6.57              8            3.3
# 28               Burundi   Africa  6.28              9            5.1
# 35                 Chile  America  2.44             30           11.8
# 43                  Cuba  America  1.55             70           10.9
# 50    Dominican.Republic  America  2.80             64           11.1
# 53                 Egypt   Africa  3.40             47           10.8
# 54           El.Salvador  America  3.09             53            9.6
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.xlabel('lifeMale')
plt.ylabel('lifeFemale')
plt.show()
